# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.describe().plot(
#     fontsize=27, 
#     figsize = (20,8), 
#     table = True,
#     colormap="rainbow",
#     kind = "area"
)

plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Iris Dataset")
# Out:
# Text(0.5, 1.0, 'General Statistics of Iris Dataset')

# %% [markdown]
# # Bar Plot

# %%
sns.countplot('Species',data=iris)
plt.show()

# %% [markdown]
# #  Pie Chart

# %%
iris['Species'].value_counts().plot.pie(
#     explode=[0.1,0.1,0.1],
#     autopct='%1.1f%%',
#     shadow=True,
#     figsize=(10,8)
)

plt.show()

# %% [markdown]
# # jointplot

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=iris, kind="reg")

# %%
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=iris, kind="kde",color='b')

# %% [markdown]
# # Facet grid plot

# %%
sns.FacetGrid(iris,hue='Species',
              size=5).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='Species',y='PetalLengthCm', data=iris, 
            order=['Iris-virginica','Iris-versicolor','Iris-setosa'],
            linewidth=2.5,
#             orient='v',
#             dodge=False
           )

# %%
iris.boxplot(by="Species", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FA5ED188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FA634A08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FA5FA7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FA6A1948>]],
#       dtype=object)

# %% [markdown]
# # Strip polt

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='Species',
                  y='SepalLengthCm',
                  data=iris,
                  edgecolor='gray',
                  size=5,
                  palette='winter',
                  orient='v')

# %% [markdown]
# # combining two plots

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='SepalLengthCm',data=iris)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray')

# %% [markdown]
# # PairPlot

# %%
sns.pairplot(iris,hue='Species')

# %%
sns.pairplot(data=iris,kind='scatter')

# %% [markdown]
# # Hist

# %%
iris.hist(edgecolor='black', linewidth=1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FD1839C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FD1D2E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FCF46DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D0FCF7E7C8>]],
#       dtype=object)

# %% [markdown]
# # SOME COOL PLOTS

# %%
from pandas.plotting import andrews_curves
andrews_curves(iris,"Species",
#               colormap='rainbow'
              )
plt.show()
plt.ioff()

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(iris, "Species")
plt.ioff()
